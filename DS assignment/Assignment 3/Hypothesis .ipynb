# %%
import pandas as pd
import numpy as np
import scipy.stats as stats
import matplotlib.pyplot as plt
import seaborn as sns
from PIL import ImageGrab
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Question 1

# %% [markdown]
#  ## Step 1:
#   ### Make Two Hypothesis ine contradicting to other
#    + **Null Hypothesis: 𝜇1=𝜇2**
#    + **Alternative Hypothesis : 𝜇1≠𝜇2**

# %% [markdown]
#  ## Step 2:
#  ### Decide a cut-off value :-
# + **significance 5%**
# + **alpha = 0.05**
#
# ### As it is two-tailed test :-
# + **alpha/2 = 0.025**

# %% [markdown]
#  ## Step 3:

# %% [markdown]
#  ### Collect Edivence

# %% [markdown]
# ### Importing File

# %%
df= pd.read_csv('Cutlets.csv')

# %%
df.describe()
# Out:
#           Unit A     Unit B
# count  35.000000  35.000000
# mean    7.019091   6.964297
# std     0.288408   0.343401
# min     6.437600   6.038000
# 25%     6.831500   6.753600
# 50%     6.943800   6.939900
# 75%     7.280550   7.195000
# max     7.516900   7.545900

# %% [markdown]
# ### Checking for null values

# %%
df.isnull().sum()
# Out:
# Unit A    0
# Unit B    0
# dtype: int64

# %% [markdown]
# ### Checking for Duplicate Values

# %%
df[df.duplicated()].shape
# Out:
# (0, 2)

# %% [markdown]
# ### Checking for data type

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35 entries, 0 to 34
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Unit A  35 non-null     float64
#  1   Unit B  35 non-null     float64
# dtypes: float64(2)
# memory usage: 692.0 bytes

# %% [markdown]
# ### Plotting the data

# %%
plt.subplots(figsize=(9,6))
plt.subplot(121)
plt.boxplot(df['Unit A'])
plt.title('Unit A')
plt.subplot(122)
plt.boxplot(df['Unit B'])
plt.title('Unit B')
plt.show()

# %%
plt.subplots(figsize=(9,6))
plt.subplot(121)
plt.hist(df['Unit A'])
plt.title('Unit A')
plt.subplot(122)
plt.hist(df['Unit B'])
plt.title('Unit B')
plt.show()

# %%
plt.figure(figsize = (8,6))
labels = ['Unit A' , 'Unit B']
sns.distplot(df['Unit A'], kde = True)
sns.distplot(df['Unit B'], kde = True)
plt.legend(labels)

# %% [markdown]
# ## Step 4

# %% [markdown]
# ### Compare Evidences wwith Hypothesis using t-statistics

# %%
statistic, p_value = stats.ttest_ind(df['Unit A'],df['Unit B'],alternative = 'two-sided')
print('p_value = ' , p_value)
# Out:
# p_value =  0.4722394724599501

# %% [markdown]
# ### Compare p_value with '𝛼' (Significane Level)

# %% [markdown]
# ### If p_value is ≠ '𝛼' we failed to reject Null Hypothesis because of lack of evidence

# %% [markdown]
# ### If p_value is = '𝛼' we reject Null Hypothesis

# %%
alpha = 0.025
print('Significance =%.3f, p=%.3f' %(alpha, p_value))
if p_value <= alpha:
    print('WE Reject Null Hypothesis' )
else:
        print('WE fail to Reject Null Hypothesis')
# Out:
# Significance =0.025, p=0.472
# WE fail to Reject Null Hypothesis

# %% [markdown]
# ### Hence,  WE fail to reject Null Hypothesis because of lack of evidence, there is no significant diffrence between the two sample

# %% [markdown]
# # Question 2

# %% [markdown]
# ### We are going to conduct aa ANOVA TEST on 4 Independent samples with   Numerical Data

# %% [markdown]
# ###  We need to chek whether the mean of any of these  samples with Numerical Data

# %% [markdown]
# ### Step 1

# %% [markdown]
# ### Make Two Hypothesis one contradicting to other

# %% [markdown]
# + **Null Hypothesis:** $\mu_1 = \mu_2$ = $\mu_3$ = $\mu_4$
# + **Alternative Hypothesis:**  Atleast one of them is Differente

# %% [markdown]
# ### Step 2

# %% [markdown]
# ### Decide a cut-off value

# %% [markdown]
# + **Significance 5%**
# + **alpha = 0.05**

# %% [markdown]
# ### Step 3

# %% [markdown]
# ### Collect evidence

# %% [markdown]
# ### Importing Files

# %%
Labtat = pd.read_csv('LabTAT.csv')

# %%
Labtat.head()
# Out:
#    Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# 0        185.35        165.53        176.70        166.13
# 1        170.49        185.91        198.45        160.79
# 2        192.77        194.92        201.23        185.18
# 3        177.33        183.00        199.61        176.42
# 4        193.41        169.57        204.63        152.60

# %% [markdown]
# ### Applying DEscriptive Statistics

# %%
Labtat.describe()
# Out:
#        Laboratory 1  Laboratory 2  Laboratory 3  Laboratory 4
# count    120.000000    120.000000    120.000000     120.00000
# mean     178.361583    178.902917    199.913250     163.68275
# std       13.173594     14.957114     16.539033      15.08508
# min      138.300000    140.550000    159.690000     124.06000
# 25%      170.335000    168.025000    188.232500     154.05000
# 50%      178.530000    178.870000    199.805000     164.42500
# 75%      186.535000    189.112500    211.332500     172.88250
# max      216.390000    217.860000    238.700000     205.18000

# %% [markdown]
# ### Checking for Null values

# %%
Labtat.isnull().sum()
# Out:
# Laboratory 1    0
# Laboratory 2    0
# Laboratory 3    0
# Laboratory 4    0
# dtype: int64

# %% [markdown]
# ### Checking for Duplicate Values

# %%
Labtat[Labtat.duplicated()].shape
# Out:
# (0, 4)

# %% [markdown]
# ### Checking the data type

# %%
Labtat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 120 entries, 0 to 119
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Laboratory 1  120 non-null    float64
#  1   Laboratory 2  120 non-null    float64
#  2   Laboratory 3  120 non-null    float64
#  3   Laboratory 4  120 non-null    float64
# dtypes: float64(4)
# memory usage: 3.9 KB

# %% [markdown]
# ### Plotting the data

# %%
plt.subplots(figsize = (16,9))
plt.subplot(221)
plt.boxplot(Labtat['Laboratory 1'])
plt.title('Laboratory 1')

plt.subplot(222)
plt.boxplot(Labtat['Laboratory 2'])
plt.title('Laboratory 2')

plt.subplot(223)
plt.boxplot(Labtat['Laboratory 3'])
plt.title('Laboratory 3')

plt.subplot(224)
plt.boxplot(Labtat['Laboratory 4'])
plt.title('Laboratory 4')

plt.show()

# %%
plt.subplots(figsize = (9,6))
plt.subplot(221)
plt.hist(Labtat['Laboratory 1'])
plt.title('Laboratory 1')

plt.subplot(222)
plt.hist(Labtat['Laboratory 2'])
plt.title('Laboratory 2')

plt.subplot(223)
plt.hist(Labtat['Laboratory 3'])
plt.title('Laboratory 3')

plt.subplot(224)
plt.hist(Labtat['Laboratory 4'])
plt.title('Laboratory4')


plt.show()

# %%
plt.figure(figsize = (8,6))
labels = ['Lab 1', 'Lab 2', 'Lab 3', 'Lab 4']
sns.distplot(Labtat['Laboratory 1'],kde = True)
sns.distplot(Labtat['Laboratory 2'],kde = True)
sns.distplot(Labtat['Laboratory 3'],kde = True)
sns.distplot(Labtat['Laboratory 4'],kde = True)
plt.legend(labels)

# %% [markdown]
# ### Step 4

# %% [markdown]
# ### Compare Evidences with Hypothesis using t-statictic

# %%
test_statistic, p_value =  stats.f_oneway(Labtat.iloc[:,0], Labtat.iloc[:,1],Labtat.iloc[:,2],Labtat.iloc[:,3])
print('p_value= ', p_value)
# Out:
# p_value=  2.1156708949992414e-57

# %% [markdown]
# ### Compare p_value with '$\alpha$'(Significane Level)

# %% [markdown]
# ### If p_value is  $\neq$'$\alpha$' we failed to reject Null Hypothesis because of laack of evidence

# %% [markdown]
# ### If p_value is $\neq$'$\alpha$' we failed to reject Null Hypothesis because of lack of evidence
# ### If p_value is = '$\alpha$' we reject Null Hypothesis

# %% [markdown]
# ### Interpreting p_value

# %%
alpha = 0.05
print('Significnace = %.3f , p = %.3f'%(alpha, p_value))
if p_value <= alpha:
    print ('We reject Null Hypothesis there is a significance difference between Tat of    reports of the laboratories')
else:
        print('We fail to reject Null Hypothesis')
# Out:
# Significnace = 0.050 , p = 0.000
# We reject Null Hypothesis there is a significance difference between Tat of    reports of the laboratories

# %% [markdown]
# ## Hence We fail to reject Null Hypothessis because of lack evidence , there is no significant diffrence between the samples

# %% [markdown]
# ## Question 3

# %% [markdown]
# ### We are going to use a Chi-Square **$\chi_2$** test with Contingency table

# %% [markdown]
# ### Step 1

# %% [markdown]
# #### Make two Hypothesis one contradicting to other

# %% [markdown]
# #### Null Hypothesis is want we want to prove

# %% [markdown]
# + **Null Hypothesis:** There is no association or deependency between the gender based buyer rations accross regions
# + **Alternative Hypothesis:** There is a significant association or dependency between the gender based buyer rations across regions

# %% [markdown]
# ## Step 2

# %% [markdown]
# Decide a cut-off value
# + **Significance 5%**
# + **alpha = 0.05**

# %% [markdown]
# ### As it is a one-tailed test

# %% [markdown]
# + **alpha = 1-0.95 = 0.05**

# %% [markdown]
# ## Step 3

# %% [markdown]
# ### Collect evidence

# %% [markdown]
# ### Importing Files

# %%
buyer = pd.read_csv('BuyerRatio (1).csv', index_col = 0)

# %%
table = [[50,142,131,70],
        [435,1523,1356,750]]

# %% [markdown]
# ### Appling Chi-Square $\chi_2$ contingency table to convert observed value into expected value

# %%
stat, p ,dof,exp = stats.chi2_contingency(buyer)
print(stat,'\n', p, '\n', dof, '\n' , exp)
# Out:
# 1.595945538661058
#  0.6603094907091882
#  3
#  [[  42.76531299  146.81287862  131.11756787   72.30424052]
#  [ 442.23468701 1518.18712138 1355.88243213  747.69575948]]

# %%
observed = np.array([50,142,131,70,435,1523,1356,750])

# %%
expected = np.array([42.76531299 , 146.81287862  ,131.11756787  , 72.30424052,442.23468701 ,1518.18712138 ,1355.88243213 , 747.69575948])

# %% [markdown]
# ## Step 4

# %% [markdown]
# ### Comparing Evidence with Hypothesis

# %%
statistics, p_value = stats.chisquare(observed, expected, ddof = 3)
print('Statistics =', statistics,'\n', 'P_value =', p_value)
# Out:
# Statistics = 1.5959455390914483
#  P_value = 0.8095206646905712

# %% [markdown]
# ### Compare P_value with '$\alpha$'

# %% [markdown]
# ### If p_value is  $/neq$ '$\alpha$' we failed to reject Null Hypothesis because of lacck of evidence
# ###  If p_value is = '$\alpha$' we reject Null Hypothesis

# %% [markdown]
# ### Interpreting p_value

# %%
alpha = 0.05
print('Significance = %.3f, p=%.3f' %(alpha, p_value))
if p_value <= alpha:
    print('We reject Null Hypothesis ')
else:
        print('We fail to reject Null hypothesis')
# Out:
# Significance = 0.050, p=0.810
# We fail to reject Null hypothesis

# %% [markdown]
# ### We fail to reject Null Hypothesis beacuse of lacck evidence. Therefore, there is no association or dependency between male-feamle buyers rations and are similar across regions. Hence , Independent samples

# %% [markdown]
# ## Question 4

# %% [markdown]
# ### We are going to conduct a Test of Independence using Chi-Square $\chi_2$ test with Contigency table

# %% [markdown]
# ### We need to check whether the mean of any  of these samples are diffrent or the same ?

# %% [markdown]
# ## Step 1

# %% [markdown]
# ### Make two Hypothesis one contradicting to other
# + **Null Hypothesis:** $\mu_1 = \mu_2$ = $\mu_3$ = $\mu_4$
# + **Alternative Hypothesis:** Atleast One of them is different

# %% [markdown]
# ## Step 2

# %% [markdown]
# ### Decide a cut-off value
# + **Significance 5%**
# + **alpha = 0.05**

# %% [markdown]
# ## Step 3

# %% [markdown]
# ### Collect evidence

# %% [markdown]
# ### Importing Files

# %%
customer= pd.read_csv('Costomer+OrderForm (1).csv')

# %%
customer.head()
# Out:
#   Phillippines   Indonesia       Malta       India
# 0   Error Free  Error Free   Defective  Error Free
# 1   Error Free  Error Free  Error Free   Defective
# 2   Error Free   Defective   Defective  Error Free
# 3   Error Free  Error Free  Error Free  Error Free
# 4   Error Free  Error Free   Defective  Error Free

# %%
customer.describe()
# Out:
#        Phillippines   Indonesia       Malta       India
# count           300         300         300         300
# unique            2           2           2           2
# top      Error Free  Error Free  Error Free  Error Free
# freq            271         267         269         280

# %%
customer.isnull().sum()
# Out:
# Phillippines    0
# Indonesia       0
# Malta           0
# India           0
# dtype: int64

# %%
customer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 300 entries, 0 to 299
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Phillippines  300 non-null    object
#  1   Indonesia     300 non-null    object
#  2   Malta         300 non-null    object
#  3   India         300 non-null    object
# dtypes: object(4)
# memory usage: 9.5+ KB

# %%
customer.value_counts()
# Out:
# Phillippines  Indonesia   Malta       India
# Error Free    Error Free  Error Free  Error Free    206
# Defective     Error Free  Error Free  Error Free     21
# Error Free    Defective   Error Free  Error Free     20
#               Error Free  Defective   Error Free     18
#                           Error Free  Defective      16
#               Defective   Defective   Error Free      9
# Defective     Error Free  Defective   Error Free      4
#               Defective   Error Free  Error Free      2
#               Error Free  Error Free  Defective       2
# Error Free    Defective   Error Free  Defective       2
# dtype: int64

# %% [markdown]
# ### Creating Contingency table

# %%
contingency_table = [[271,267,269,280],[29,33,31,20]]

# %%
print(contingency_table)
# Out:
# [[271, 267, 269, 280], [29, 33, 31, 20]]

# %% [markdown]
# ### Calculating Expected Values for Observed data

# %%
stat , p , df ,  exp = stats.chi2_contingency(contingency_table)
print('Statistics = ', stats,'\n', 'P_value =' , p, '\n', 'degree of freedom=' , df, '\n', 'Expected Values= ',exp)
# Out:
# Statistics =  <module 'scipy.stats' from 'C:\\Users\\Awadhesh pal\\anaconda3\\Lib\\site-packages\\scipy\\stats\\__init__.py'>
#  P_value = 0.2771020991233135
#  degree of freedom= 3
#  Expected Values=  [[271.75 271.75 271.75 271.75]
#  [ 28.25  28.25  28.25  28.25]]

# %% [markdown]
# ### Defining Expected values aand observed values

# %%
observed = np.array([271, 267, 269, 280, 29, 33, 31, 20])
expected = np.array([271.75 ,271.75 ,271.75 ,271.75,28.25 , 28.25  ,28.25 , 28.25])

# %% [markdown]
# ## Step 4

# %% [markdown]
# ### Compare Evidence with Hypothesis using t_statictic

# %%
test_statistic , p_value = stats.chisquare(observed, expected, ddof = df)
print('test Statistic = ', test_statistic,'\n','p_value=' , p_value)
# Out:
# test Statistic =  3.858960685820355
#  p_value= 0.4254298144535761

# %%
alpha = 0.05
print('Significnace = %.3f,p=%.3f' % (alpha, p_value))
if p_value <= alpha:
    print('We reject Null Hypothesis  ')
else:
        print('We fail to reject Null Hypothesis')
# Out:
# Significnace = 0.050,p=0.425
# We fail to reject Null Hypothesis

# %% [markdown]
# ## We fail to reject Null Hypothesis because of lack of evidence
